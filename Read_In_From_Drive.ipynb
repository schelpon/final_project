# %%
import numpy as np
import xarray as xr
import pandas as pd 
import datetime 

from matplotlib import pyplot as plt
import matplotlib.ticker as mticker
from mpl_toolkits import mplot3d
import matplotlib.dates as mdates

# %matplotlib inline
# %config inlinebackend.figure_format='retina'

# %%
# load in contrast rf11 file 
# https://drive.google.com/file/d/1xVarpVV6Su5ophCqOpG14D4lHrF1xHBa/view?usp=sharing
myurl_start = 'https://docs.google.com/uc?export=download&id='

! wget -O contrast_file 'https://docs.google.com/uc?export=download&id=1xVarpVV6Su5ophCqOpG14D4lHrF1xHBa'
# Out:
# --2019-11-22 10:24:32--  https://docs.google.com/uc?export=download&id=1xVarpVV6Su5ophCqOpG14D4lHrF1xHBa
# Resolving docs.google.com... 2607:f8b0:4006:818::200e, 172.217.3.110, 172.217.10.78, ...
# Connecting to docs.google.com|2607:f8b0:4006:818::200e|:443... failed: Operation timed out.
# Connecting to docs.google.com|172.217.3.110|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-08-3s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/qeus1gmoobr5ikb8oqjm8i1rk4qvv0ce/1574431200000/10967756465562109017/*/1xVarpVV6Su5ophCqOpG14D4lHrF1xHBa?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-11-22 10:25:48--  https://doc-08-3s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/qeus1gmoobr5ikb8oqjm8i1rk4qvv0ce/1574431200000/10967756465562109017/*/1xVarpVV6Su5ophCqOpG14D4lHrF1xHBa?e=download
# Resolving doc-08-3s-docs.googleusercontent.com... 2607:f8b0:4006:81a::2001, 172.217.12.129
# Connecting to doc-08-3s-docs.googleusercontent.com|2607:f8b0:4006:81a::2001|:443... failed: Operation timed out.
# Connecting to doc-08-3s-docs.googleusercontent.com|172.217.12.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 279228 (273K) [application/x-netcdf]
# Saving to: 'contrast_file'
#
# contrast_file       100%[===================>] 272.68K  --.-KB/s    in 0.1s
#
# 2019-11-22 10:27:04 (2.59 MB/s) - 'contrast_file' saved [279228/279228]

# %%
# read in the file 
toga = xr.open_dataset('contrast_file')
toga
# Out:
# <xarray.Dataset>
# Dimensions:                           (Time: 196)
# Coordinates:
#   * Time                              (Time) datetime64[ns] 2014-02-12T23:59:25 ... 2014-02-13T06:29:25
# Data variables:
#     Time_UTC                          (Time) datetime64[ns] ...
#     FLT_HH                            (Time) timedelta64[ns] ...
#     FLT_MM                            (Time) timedelta64[ns] ...
#     FLT_SS                            (Time) timedelta64[ns] ...
#     UTC_HH                            (Time) timedelta64[ns] ...
#     UTC_MM                            (Time) timedelta64[ns] ...
#     UTC_SS                            (Time) timedelta64[ns] ...
#     GALT_A                            (Time) float32 ...
#     GGALT                             (Time) float32 ...
#     GGEOIDHT                          (Time) float32 ...
#     GGLAT                             (Time) float32 ...
#     GGLON                             (Time) float32 ...
#     GGQUAL                            (Time) float32 ...
#     GGSPD                             (Time) float32 ...
#     PITCH                             (Time) float32 ...
#     RICE                              (Time) float32 ...
#     ROLL                              (Time) float32 ...
#     THDG                              (Time) float32 ...
#     VISBC                             (Time) float32 ...
#     VISTC                             (Time) float32 ...
#     ATX                               (Time) float32 ...
#     CONCD_RWOO                        (Time) float32 ...
#     CONCU100_RWOI                     (Time) float32 ...
#     CONCU500_RWOI                     (Time) float32 ...
#     CONCU_RWOI                        (Time) float32 ...
#     CONCV_VXL                         (Time) float32 ...
#     DBARD_RWOO                        (Time) float32 ...
#     DBARU_RWOI                        (Time) float32 ...
#     DPXC                              (Time) float32 ...
#     DP_DPL                            (Time) float32 ...
#     DP_DPR                            (Time) float32 ...
#     DP_VXL                            (Time) float32 ...
#     EW_DPL                            (Time) float32 ...
#     EW_DPR                            (Time) float32 ...
#     EW_VXL                            (Time) float32 ...
#     LATC                              (Time) float32 ...
#     LONC                              (Time) float32 ...
#     MR                                (Time) float32 ...
#     PALT                              (Time) float32 ...
#     PALTF                             (Time) float32 ...
#     PLWCC                             (Time) float32 ...
#     PLWCD_RWOO                        (Time) float32 ...
#     PSXC                              (Time) float32 ...
#     RHODT                             (Time) float32 ...
#     RHUM                              (Time) float32 ...
#     SOLAZ                             (Time) float32 ...
#     SOLDE                             (Time) float32 ...
#     SOLEL                             (Time) float32 ...
#     SOLZE                             (Time) float32 ...
#     TASX                              (Time) float32 ...
#     THETA                             (Time) float32 ...
#     THETAE                            (Time) float32 ...
#     THETAQ                            (Time) float32 ...
#     THETAV                            (Time) float32 ...
#     TVIR                              (Time) float32 ...
#     UIC                               (Time) float32 ...
#     VIC                               (Time) float32 ...
#     VMR_VXL                           (Time) float32 ...
#     WDC                               (Time) float32 ...
#     WIC                               (Time) float32 ...
#     WSC                               (Time) float32 ...
#     Profile_Number                    (Time) float32 ...
#     Profile_Direction                 (Time) float32 ...
#     C2H6_Ethane                       (Time) float32 ...
#     C2H2_Ethyne                       (Time) float32 ...
#     C3H8_Propane                      (Time) float32 ...
#     C4H10_Isobutane                   (Time) float32 ...
#     C4H10_nButane                     (Time) float32 ...
#     C5H12_Isopentane                  (Time) float32 ...
#     C5H12_nPentane                    (Time) float32 ...
#     C5H8_Isoprene                     (Time) float32 ...
#     C6H6_Benzene                      (Time) float32 ...
#     OCS_Carbonyl_sulfide              (Time) float32 ...
#     C2H6S_Dimethyl_sulfide            (Time) float32 ...
#     CCl2F2_CFC_12                     (Time) float32 ...
#     CCl3F_CFC_11                      (Time) float32 ...
#     CCl2FCCl2F_CFC112                 (Time) float32 ...
#     CCl3CClF2_CFC_112a                (Time) float32 ...
#     C2Cl3F3_CFC_113                   (Time) float32 ...
#     C2Cl2F4_CFC_114                   (Time) float32 ...
#     CHClF2_HCFC_22                    (Time) float32 ...
#     CH3CClF2_HCFC_142b                (Time) float32 ...
#     CH3CCl2F_HCFC_141b                (Time) float32 ...
#     CH2FCF3_HFC_134a                  (Time) float32 ...
#     C4H5F5_HFC365mfc                  (Time) float32 ...
#     CH3Cl_Methyl_chloride             (Time) float32 ...
#     CH3Br_Methyl_bromide              (Time) float32 ...
#     CH3I_Methyl_iodide                (Time) float32 ...
#     CH2Cl2_Methylene_chloride         (Time) float32 ...
#     CHCl3_Chloroform                  (Time) float32 ...
#     CH3CCl3_Methyl_chloroform         (Time) float32 ...
#     CCl4_Carbon_tetrachloride         (Time) float32 ...
#     C2H4Cl2_1_2_Dichloroethane        (Time) float32 ...
#     C2HCl3_Trichloroethylene          (Time) float32 ...
#     C2Cl4_Tetrachloroethylene         (Time) float32 ...
#     C6H5Cl_Chlorobenzene              (Time) float32 ...
#     CBrClF2_Halon_1211                (Time) float32 ...
#     C2Br2F4_Halon_2402                (Time) float32 ...
#     CH2BrCl_Bromochloromethane        (Time) float32 ...
#     CH2Br2_Methylene_bromide          (Time) float32 ...
#     CHBrCl2_Bromodichloromethane      (Time) float32 ...
#     CHBr2Cl_Dibromochloromethane      (Time) float32 ...
#     CHBr3_Bromoform                   (Time) float32 ...
#     CH3ONO2_Methyl_nitrate            (Time) float32 ...
#     C2H5ONO2_Ethyl_nitrate            (Time) float32 ...
#     C3H7NO3_Isopropyl_nitrate         (Time) float32 ...
#     C4H9NO3_2_Butyl_nitrate           (Time) float32 ...
#     C4H9NO3_n_Butyl_nitrate           (Time) float32 ...
#     C5H11NO3_3_pentyl_nitrate         (Time) float32 ...
#     C5H11NO3_2_pentyl_nitrate         (Time) float32 ...
#     CO                                (Time) float32 ...
#     CO2                               (Time) float32 ...
#     Methane                           (Time) float32 ...
#     DOAS_BrO                          (Time) float32 ...
#     DOAS_delta_BrO                    (Time) float32 ...
#     BrO                               (Time) float32 ...
#     HOBr+Br2                          (Time) float32 ...
#     Br_key                            (Time) float32 ...
#     N2O5                              (Time) float32 ...
#     O3->O2+O(1D)                      (Time) float32 ...
#     NO2->NO+O(3P)                     (Time) float32 ...
#     H2O2->2OH                         (Time) float32 ...
#     N2O5->NO3+NO2                     (Time) float32 ...
#     HNO2->OH+NO                       (Time) float32 ...
#     HNO3->OH+NO2                      (Time) float32 ...
#     HNO4->HO2+NO2                     (Time) float32 ...
#     CH2O->H+HCO                       (Time) float32 ...
#     CH2O->H2+CO                       (Time) float32 ...
#     CH3CHO->CH3+HCO                   (Time) float32 ...
#     C2H5CHO->C2H5+HCO                 (Time) float32 ...
#     CH3OOH->CH3O+OH                   (Time) float32 ...
#     CH3ONO2->CH3O+NO2                 (Time) float32 ...
#     CH3CH2ONO2->CH3CH2O+NO2           (Time) float32 ...
#     CH3CO(OONO2)[PAN]->CH3CO(OO)+NO2  (Time) float32 ...
#     CH3CO(OONO2)[PAN]->CH3CO(O)+NO3   (Time) float32 ...
#     CH2=C(CH3)CHO->Products           (Time) float32 ...
#     CH3COCH=CH2->Products             (Time) float32 ...
#     CH3COCH3->CH3CO+CH3               (Time) float32 ...
#     CH3COCH2CH3->CH3CO+CH2CH3         (Time) float32 ...
#     CHOCHO->HCO+HCO                   (Time) float32 ...
#     CHOCHO->H2+2CO                    (Time) float32 ...
#     CHOCHO->CH2O+CO                   (Time) float32 ...
#     CH3COCHO->CH3CO+HCO               (Time) float32 ...
#     Cl2->Cl+Cl                        (Time) float32 ...
#     ClO->Cl+O(3P)                     (Time) float32 ...
#     ClNO2->Cl+NO2                     (Time) float32 ...
#     ClONO->Cl+NO2                     (Time) float32 ...
#     ClONO2->Cl+NO3                    (Time) float32 ...
#     ClONO2->ClO+NO2                   (Time) float32 ...
#     Br2->Br+Br                        (Time) float32 ...
#     BrO->Br+O                         (Time) float32 ...
#     HOBr->OH+Br                       (Time) float32 ...
#     BrNO->Br+NO                       (Time) float32 ...
#     BrONO->Br+NO2                     (Time) float32 ...
#     BrONO->BrO+NO                     (Time) float32 ...
#     BrNO2->Br+NO2                     (Time) float32 ...
#     BrONO2->BrO+NO2                   (Time) float32 ...
#     BrONO2->Br+NO3                    (Time) float32 ...
#     BrCl->Br+Cl                       (Time) float32 ...
#     CHBr3->Products                   (Time) float32 ...
#     CH3CH2CH2CHO->C3H7+HCO            (Time) float32 ...
#     CH3CH2CH2CHO->C2H4+CH2CHOH        (Time) float32 ...
#     Br2O->Products                    (Time) float32 ...
#     HCHO                              (Time) float32 ...
#     NO_pptv                           (Time) float32 ...
#     NO2_pptv                          (Time) float32 ...
#     XNO2_pptv                         (Time) float32 ...
#     O3_ppbv                           (Time) float32 ...
#     NO_precErr_pptv                   (Time) float32 ...
#     NO_biasErr_pptv                   (Time) float32 ...
#     NO2_precErr_pptv                  (Time) float32 ...
#     NO2_biasErr_pptv                  (Time) float32 ...
#     O3_precErr_ppbv                   (Time) float32 ...
#     O3_biasErr_ppbv                   (Time) float32 ...
#     C3H8                              (Time) float32 ...
#     CH2O                              (Time) float32 ...
#     OCS                               (Time) float32 ...
#     CFC12                             (Time) float32 ...
#     CFC114                            (Time) float32 ...
#     HCN                               (Time) float32 ...
#     i_Butane                          (Time) float32 ...
#     n_Butane                          (Time) float32 ...
#     Methyl_Chloride                   (Time) float32 ...
#     Acetaldehyde                      (Time) float32 ...
#     i_Butene_1_Butene                 (Time) float32 ...
#     Methyl_Bromide                    (Time) float32 ...
#     i_Pentane                         (Time) float32 ...
#     n_Pentane                         (Time) float32 ...
#     Methanol                          (Time) float32 ...
#     Ethanol                           (Time) float32 ...
#     Acrolein                          (Time) float32 ...
#     Isoprene                          (Time) float32 ...
#     Methyl_Iodide                     (Time) float32 ...
#     DMS                               (Time) float32 ...
#     Bromoethane                       (Time) float32 ...
#     CFC11                             (Time) float32 ...
#     CFC113                            (Time) float32 ...
#     Propanal                          (Time) float32 ...
#     Acetone                           (Time) float32 ...
#     2_Methylpentane                   (Time) float32 ...
#     3_Methylpentane                   (Time) float32 ...
#     n_Hexane                          (Time) float32 ...
#     Dichloromethane                   (Time) float32 ...
#     2_Propanol                        (Time) float32 ...
#     CH3CN                             (Time) float32 ...
#     MethylNitrate                     (Time) float32 ...
#     PAN                               (Time) float32 ...
#     MACR                              (Time) float32 ...
#     MVK                               (Time) float32 ...
#     3_MethylFuran                     (Time) float32 ...
#     Butanal                           (Time) float32 ...
#     MEK                               (Time) float32 ...
#     Ethyl_Iodide                      (Time) float32 ...
#     MTBE                              (Time) float32 ...
#     Chloroform                        (Time) float32 ...
#     Carbon_Tetrachloride              (Time) float32 ...
#     Bromochloromethane                (Time) float32 ...
#     EthylNitrate                      (Time) float32 ...
#     I_PropylNitrate                   (Time) float32 ...
#     MBO                               (Time) float32 ...
#     Benzene                           (Time) float32 ...
#     n_Heptane                         (Time) float32 ...
#     Pentanal                          (Time) float32 ...
#     2_Pentanone                       (Time) float32 ...
#     3_Pentanone                       (Time) float32 ...
#     Bromodichloromethane              (Time) float32 ...
#     Dibromomethane                    (Time) float32 ...
#     Chloroiodomethane                 (Time) float32 ...
#     tert_ButylNitrate                 (Time) float32 ...
#     I_ButylNitrate                    (Time) float32 ...
#     2_ButylNitrate_n_ButylNitrate     (Time) float32 ...
#     2_PentylNitrate_3_PentylNitrate   (Time) float32 ...
#     Toluene                           (Time) float32 ...
#     Ethylbenzene_m_p_Xylene           (Time) float32 ...
#     o_Xylene                          (Time) float32 ...
#     Tetrachloroethylene               (Time) float32 ...
#     Dibromochloromethane              (Time) float32 ...
#     Bromoiodomethane                  (Time) float32 ...
#     Chlorobenzene                     (Time) float32 ...
#     Bromoform                         (Time) float32 ...
#     Alpha_Pinene                      (Time) float32 ...
#     Camphene                          (Time) float32 ...
#     Beta_Pinene                       (Time) float32 ...
#     d_Limonene_3_Carene               (Time) float32 ...
#     Alpha_Terpinene                   (Time) float32 ...
#     Para_Cymene                       (Time) float32 ...
#     1_2_4_Trimethylbenzene            (Time) float32 ...
#     1_3_5_Trimethylbenzene            (Time) float32 ...
#     1_2_3_Trimethylbenzene            (Time) float32 ...
#     Diiodomethane                     (Time) float32 ...
#     1_3_Dichlorobenzene               (Time) float32 ...
#     1_2_Dichlorobenzene               (Time) float32 ...
# Attributes:
#     Institution:                     NCAR Atmospheric Chemistry Observations ...
#     Address:                         P.O. Box 3000, Boulder, CO 80307-3000
#     Phone:                           (303) 497-8194
#     Author:                          Shawn Honomichl
#     Author_Email:                    shawnh@ucar.edu
#     Nomenclature_compliance_note:    Spaces removed from variable names when ...
#     Merged_NetCDF_Creation_Date:     Wed Aug 24 21:12:41 2016
#     Project_Name:                    CONTRAST
#     Aircraft_Type:                   GV
#     Aircraft_Tail:                   N677F
#     Flight:                          rf11
#     Flight_Date:                     02/12/2014
#     Data_Aligned_to:                 TOGA
#     time_coordinate:                 Time
#     Master_Time_Units:               Seconds
#     Approximate_Data_Time_Interval:  120.0
#     Data_Collection_Duration:        6.50 Hours
#     Time_Range:                      23:59:25-06:29:25
#     time_coverage_start:             2014-02-12T23:59:43 +0000
#     time_coverage_end:               2014-02-13T06:29:43 +0000
#     Included_Instrument_Data:        Aircraft_NC,PROFILES,AWAS,CO,CO2CH4,DOAS...
#     Aircraft_NC_Input_File:          CONTRASTrf11.nc
#     PROFILES_Input_File:             CONTRAST-PROFILES_GV_20140212_R1.ict
#     AWAS_Input_File:                 CONTRAST-AWAS_GV_20140212_R0.ict
#     CO_Input_File:                   CONTRAST-CO_GV_20140212_R1.ict
#     CO2CH4_Input_File:               CONTRAST-CO2CH4_GV_20140212_R1.ict
#     DOAS_Input_File:                 n/a
#     GTCIMS_Input_File:               CONTRAST-GTCIMS_GV_20140212_R2.ict
#     HARP_Input_File:                 CONTRAST-HARP_GV_20140212_R1.ict
#     ISAF_Input_File:                 CONTRAST-ISAF_GV_20140212_R0.ict
#     NONO2O3_Input_File:              CONTRAST-NONO2O3_GV_20140212_R3.ict
#     TOGA_Input_File:                 CONTRAST-TOGA_GV_20140212_R2.ict
#     latitude_coordinate:             LATC
#     longitude_coordinate:            LONC
#     zaxis_coordinate:                PSXC
#     geospatial_lat_min:              6.21566
#     geospatial_lat_max:              13.68643
#     geospatial_lon_min:              135.21407
#     geospatial_lon_max:              146.10963
#     geospatial_vertical_min:         43.49658
#     geospatial_vertical_max:         14089.178
#     geospatial_vertical_positive:    up
#     geospatial_vertical_units:       m
#     fill_values:                     -99999.0
#     Categories:                      AWAS,Aircraft_NC,CO,DOAS_[MISSING],GTCIM...
#     landmarks:                       19.746 -155.457 Hawaii,34.481 -118.043 D...

# %%
# load in small camchem rf11 file 
# https://drive.google.com/file/d/1XnQLD3iAt6ALa1D8P1GMZTmK1317ZPE8/view?usp=sharing
myurl_start = 'https://docs.google.com/uc?export=download&id='

! wget -O camchem_file 'https://docs.google.com/uc?export=download&id=1XnQLD3iAt6ALa1D8P1GMZTmK1317ZPE8'
# Out:
# --2019-11-22 10:45:53--  https://docs.google.com/uc?export=download&id=1XnQLD3iAt6ALa1D8P1GMZTmK1317ZPE8
# Resolving docs.google.com... 2607:f8b0:4006:81a::200e, 172.217.3.110
# Connecting to docs.google.com|2607:f8b0:4006:81a::200e|:443... failed: Operation timed out.
# Connecting to docs.google.com|172.217.3.110|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0k-3s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/okavt0uodsr8skvuul5m3rfcsb279ck9/1574431200000/10967756465562109017/*/1XnQLD3iAt6ALa1D8P1GMZTmK1317ZPE8?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-11-22 10:47:09--  https://doc-0k-3s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/okavt0uodsr8skvuul5m3rfcsb279ck9/1574431200000/10967756465562109017/*/1XnQLD3iAt6ALa1D8P1GMZTmK1317ZPE8?e=download
# Resolving doc-0k-3s-docs.googleusercontent.com... 2607:f8b0:4006:812::2001, 172.217.11.1
# Connecting to doc-0k-3s-docs.googleusercontent.com|2607:f8b0:4006:812::2001|:443... failed: Operation timed out.
# Connecting to doc-0k-3s-docs.googleusercontent.com|172.217.11.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 569630 (556K) [application/x-netcdf]
# Saving to: 'camchem_file'
#
# camchem_file        100%[===================>] 556.28K  2.16MB/s    in 0.3s
#
# 2019-11-22 10:48:29 (2.16 MB/s) - 'camchem_file' saved [569630/569630]

# %%
cam = xr.open_dataset('camchem_file')
cam
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 32, lev: 56, lon: 25, time: 1)
# Coordinates:
#   * lon      (lon) float64 130.0 131.2 132.5 133.8 ... 156.2 157.5 158.8 160.0
#   * lev      (lev) float64 1.868 2.353 2.948 3.677 ... 947.5 962.5 977.5 992.5
#   * lat      (lat) float64 0.4712 1.414 2.356 3.298 ... 26.86 27.8 28.74 29.69
#   * time     (time) object 2014-12-01 00:00:00
# Data variables:
#     DMS      (time, lev, lat, lon) float32 ...
#     CHBR3    (time, lev, lat, lon) float32 ...
#     NO2      (time, lev, lat, lon) float32 ...
# Attributes:
#     Conventions:      CF-1.0
#     source:           CAM
#     case:             f.e11.TS1IREFC1SD.f09.f09.ccmi34.Aircraft_2014-2016.cy.001
#     title:            UNSET
#     logname:          dkin
#     host:             r1i4n16
#     Version:          $Name$
#     revision_Id:      $Id$
#     initial_file:     /glade2/scratch2/dkin/f.e11.TS1IREFC1SD.f09.f09.ccmi34....
#     topography_file:  /glade/p/acd/tilmes/inputdata/topo/USGS-gtopo30_0.9x1.2...
