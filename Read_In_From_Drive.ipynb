# %%
url = 'https://drive.google.com/file/d/1jiUsVohl4zgVs-SNifFJtHh8IMOPzAQz/view?usp=sharing'
FILEID = '1jiUsVohl4zgVs-SNifFJtHh8IMOPzAQz'
myurl = 'https://docs.google.com/uc?export=download&id='+FILEID
# Out:
# 'https://docs.google.com/uc?export=download&id=1jiUsVohl4zgVs-SNifFJtHh8IMOPzAQz'

# %%
! wget -O file 'https://docs.google.com/uc?export=download&id=1jiUsVohl4zgVs-SNifFJtHh8IMOPzAQz'
# Out:
# --2019-11-21 22:38:55--  https://docs.google.com/uc?export=download&id=1jiUsVohl4zgVs-SNifFJtHh8IMOPzAQz
# Resolving docs.google.com... 2607:f8b0:4006:810::200e, 172.217.10.14
# Connecting to docs.google.com|2607:f8b0:4006:810::200e|:443... failed: Operation timed out.
# Connecting to docs.google.com|172.217.10.14|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-3s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/v59vb8bannrrfqpfqtvp7ja75jtlbcua/1574388000000/10967756465562109017/*/1jiUsVohl4zgVs-SNifFJtHh8IMOPzAQz?e=download [following]
# ...
# --2019-11-21 22:40:12--  https://doc-0c-3s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/v59vb8bannrrfqpfqtvp7ja75jtlbcua/1574388000000/10967756465562109017/*/1jiUsVohl4zgVs-SNifFJtHh8IMOPzAQz?e=download
# Resolving doc-0c-3s-docs.googleusercontent.com... 2607:f8b0:4006:819::2001, 172.217.10.225
# ...

# %%
import numpy as np
import xarray as xr
import pandas as pd 
import datetime 

from matplotlib import pyplot as plt
import matplotlib.ticker as mticker
from mpl_toolkits import mplot3d
import matplotlib.dates as mdates

# %matplotlib inline
# %config inlinebackend.figure_format='retina'

# %%
ds = xr.open_dataset('/Users/schelpon/Desktop/Python/file')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                           (Time: 23161)
# Coordinates:
#   * Time                              (Time) datetime64[ns] 2014-01-28T23:50:00 ... 2014-01-29T06:16:00
# Data variables:
#     Time_UTC                          (Time) datetime64[ns] ...
#     FLT_HH                            (Time) timedelta64[ns] ...
#     FLT_MM                            (Time) timedelta64[ns] ...
#     FLT_SS                            (Time) timedelta64[ns] ...
#     UTC_HH                            (Time) timedelta64[ns] ...
#     UTC_MM                            (Time) timedelta64[ns] ...
#     UTC_SS                            (Time) timedelta64[ns] ...
#     Profile_Number                    (Time) float32 ...
#     C2H6_Ethane                       (Time) float32 ...
#     C2H2_Ethyne                       (Time) float32 ...
#     C3H8_Propane                      (Time) float32 ...
#     C4H10_Isobutane                   (Time) float32 ...
# ...
